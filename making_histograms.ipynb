# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_pickle('tickle_my.pkl')
df.groupby('genre').agg('count')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: FutureWarning: 'genre' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#             index  song  artist  lyrics
# genre
# Country      2000  2000    2000    2000
# Electronic   2000  2000    2000    2000
# Folk         2000  2000    2000    2000
# Hip-Hop      2000  2000    2000    2000
# Indie        2000  2000    2000    2000
# Jazz         2000  2000    2000    2000
# Metal        2000  2000    2000    2000
# Pop          2000  2000    2000    2000
# R&B          2000  2000    2000    2000
# Rock         2000  2000    2000    2000

# %%
df = pd.read_pickle('love.pkl')
genres = ['Country', 'Electronic', 'Folk', 'Hip-Hop', 'Indie', 'Jazz', 'Metal',
         'Pop', 'R&B', 'Rock']
# genres = ['Country', 'Electronic', 'Hip-Hop', 'Indie', 'Jazz',
#          'R&B']
for name in genres:
    print(name)
    genre_name = name
    genre = df[genre_name]
    genre.columns = ['song_num', 'cos_sim']
    data = np.array(genre.tolist())
    data = data[np.logical_not(np.isnan(data))]
    print(len(data))
    binwidth = .05
    print(min(data))
    plt.gcf().clear()
    fig = plt.hist(data, histtype='bar', bins=np.arange(0.1, 0.6 + binwidth, binwidth), rwidth=.8)
#     fig = plt.hist(data, histtype='bar', normed=True, bins=10)
    plt.title(genre_name+" Love Cosine Similarity")
    plt.xlabel("Cosine Similarity")
    plt.ylabel("Frequency")
    plt.savefig(genre_name+"_love.svg")
# Out:
# Country
# 2000
# 0.111876991796
# Electronic
# 2000
# 0.0790551043966
# Folk
# 1993
# 0.0621195213521
# Hip-Hop
# 2000
# 0.0850700063558
# Indie
# 2000
# 0.0438460380167
# Jazz
# 2000
# 0.102749425418
# Metal
# 1999
# 0.045079785466
# Pop
# 1999
# 0.0577137330135
# R&B
# 2000
# 0.11621430985
# Rock
# 1992
# 0.0038717558412

# %%
dfh1 = pd.read_pickle('happytest.pkl')
dfh2 = pd.read_pickle('hatetest.pkl')
dfa = pd.read_pickle('lovetest.pkl')
dfs = pd.read_pickle('sadtest.pkl')

# %%
import csv
test_songs = []
cos_sim = {}
with open('Lyrics.csv') as f:
    songs = csv.reader(f, delimiter=',')
    for row in songs:
        print(row[0])
        print(row[1])
        if row[0] != 'Artist':
            test_songs.append((row[0], row[1]))
# Out:
# index
# song
# 0
# ego-remix
# 1
# then-tell-me
# 2
# honesty
# 3
# you-are-my-rock
# 4
# black-culture
# 5
# all-i-could-do-was-cry
# 6
# once-in-a-lifetime
# 7
# waiting
# 8
# slow-love
# 9
# why-don-t-you-love-me
# 10
# save-the-hero
# 11
# telephone
# 12
# ice-cream-truck
# 13
# no-broken-hearted-girl
# 14
# control
# 15
# i-m-alone-now
# 16
# poison
# 17
# world-wide-women
# 18
# beautiful-liar
# 19
# beautiful-liar-spanish
# 20
# beautiful-liar-spanglish-version
# 21
# bienvenue
# 22
# beutiful-liar-remix
# 23
# he-still-loves-me-f-choir-from-fighting-temptations
# 24
# bello-embustero
# 25
# irreplable
# 26
# the-first-day
# 27
# my-man
# 28
# what-s-it-gonna-be
# 29
# if
# 30
# a-girl-with-no-name
# 31
# bello-embustero-beautiful-liar-spanish-version
# 32
# vois-sur-ton-chemin
# 33
# flaws-all
# 34
# i-can-t-take-no-more
# 35
# bonnie-and-clyde-ft-jay-z
# 36
# keep-givin-your-love-to-me
# 37
# listen
# 38
# welcome-to-hollywood
# 39
# my-first-time
# 40
# still-in-love
# 41
# daddy-hidden-track
# 42
# angel
# 43
# diamonds
# 44
# everthing-i-do
# 45
# world-wide-woman-www
# 46
# what-s-good-with-you
# 47
# amor-gitano
# 48
# oye-listen-spanish-version
# 49
# irreemplazable-nortena-remix
# 50
# the-joy-of-pepsi-carmen
# 51
# irreemplazable-irreplaceable-spanish-version
# 52
# if-eu-asian-australian-edition
# 53
# brown-eyes
# 54
# why-me-lord
# 55
# back-to-black
# 56
# mine
# 57
# superpower
# 58
# haunted
# 59
# flawless
# 60
# partition
# 61
# ghost
# 62
# xo
# 63
# single-ladies-put-a-ring-on-it
# 64
# on-the-run
# 65
# no-angel
# 66
# rocket
# 67
# blow
# 68
# grown-woman
# 69
# part-ii-on-the-run
# 70
# standing-on-the-sun
# 71
# blue
# 72
# rise-up
# 73
# bow-down-i-been-on
# 74
# pretty-hurts
# 75
# heaven
# 76
# yonce
# 77
# jealous
# 78
# god-made-you-beautiful
# 79
# drunk-in-love
# 80
# baby-you-re-the-only-man
# 81
# blind-trust
# 82
# hair-crazy-in-love
# 83
# i-m-glad-there-s-you
# 84
# ice-cream
# 85
# freakdum-dresses
# 86
# hope-for-haiti-now
# 87
# lesten
# 88
# run-the-world-girls-remix
# 89
# helo
# 90
# daddy
# 91
# speechless
# 92
# cards-never-lie
# 93
# listen-hidden-track
# 94
# have-your-way
# 95
# get-me-bodied
# 96
# be-with-you
# 97
# after-all-is-said-and-done
# 98
# everything-i-do
# 99
# lost-yo-mind
# 100
# ring-the-alarm
# 101
# oye-su-canto
# 102
# naughty-girl
# 103
# gift-from-virgo
# 104
# dangerously-in-love
# 105
# check-on-it
# 106
# encore-for-the-fans-bonus-track
# 107
# the-closer-i-get-to-you
# 108
# i-m-leaving
# 109
# creole-japan-bonus-track
# 110
# he-s-my-man
# 111
# in-da-club-remix
# 112
# kitty-kat
# 113
# get-me-bodied-extended-remix-bonus-track
# 114
# work-it-out
# 115
# upgrade-u
# 116
# summertime-w-p-diddy
# 117
# wishing-on-a-star
# 118
# stop-that
# 119
# me-myself-and-i
# 120
# resentment
# 121
# summertime
# 122
# irremplazable-irreplaceable-spanish-version
# 123
# he-still-loves-me
# 124
# dangerously-in-love-2
# 125
# lost-yo-mind-itunes-pre-order-exclusive
# 126
# baby-boy
# 127
# hip-hop-star
# 128
# signs
# 129
# naughty-girl-remix
# 130
# sexy-lil-thug-remix
# 131
# the-last-great-seduction
# 132
# deja-vu-spanglish-version
# 133
# that-s-how-you-like-it
# 134
# cant-take-nomore
# 135
# crazy-in-love
# 136
# keep-giving-your-love-to-me
# 137
# irreplaceable
# 138
# irreplaceable-remix
# 139
# back-up
# 140
# hey-ladies
# 141
# yes
# 142
# if-looks-could-kill
# 143
# a-woman-like-me
# 144
# my-heart-still-beats
# 145
# time-to-come-home
# 146
# green-light
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-33-b83c9c64ed3a> in <module>()
#       4 with open('Lyrics.csv') as f:
#       5     songs = csv.reader(f, delimiter=',')
# ----> 6     for row in songs:
#       7         print(row[0])
#       8         print(row[1])
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 7108: character maps to <undefined>

# %%
happy = dfh1.tolist()
i = 0
for value in happy:
    cos_sim[test_songs[i][1]] = []
    cos_sim[test_songs[i][1]].append(value)
    i+=1
hate = dfh2.tolist()
i = 0
for value in hate:
    cos_sim[test_songs[i][1]].append(value)
    i+=1
love = dfa.tolist()
i = 0
for value in love:
    cos_sim[test_songs[i][1]].append(value)
    i+=1
sad = dfs.tolist()
i = 0
for value in sad:
    cos_sim[test_songs[i][1]].append(value)
    i+=1
print(cos_sim)
# Out:
# {'song': [0.32556193644099224, 0.22631293464604638, 0.30357257109022256, 0.398654957721428], 'ego-remix': [0.40511656177228483, 0.2407950904288218, 0.27599055051522786, 0.41873723780541583], 'then-tell-me': [0.35782650107024183, 0.24740572530021182, 0.3555711935069523, 0.40093764179542374], 'honesty': [0.4995553400498957, 0.350520766500172, 0.46119483110523185, 0.421013858220757], 'you-are-my-rock': [0.4573520013478285, 0.28431275473681245, 0.49495460279512216, 0.4233194052391503], 'black-culture': [0.34566999995273007, 0.2003639177309171, 0.4023620717898138, 0.3574204309568076], 'all-i-could-do-was-cry': [0.426506551203229, 0.25369822001114734, 0.32330730109845646, 0.4612031544267265], 'once-in-a-lifetime': [0.38057608680352495, 0.2358070600414518, 0.25012659390930825, 0.4109036214264351], 'waiting': [0.31663854213827325, 0.22294962622482606, 0.3076771962550744, 0.3716847472528127], 'slow-love': [0.34540076616840043, 0.2410459704402548, 0.23695973478607932, 0.43986843883141097], 'why-don-t-you-love-me': [0.40475672956367187, 0.28012418951902035, 0.4136658420024277, 0.45900971787313755], 'save-the-hero': [0.3995109609135853, 0.2248965400975766, 0.39303214231641415, 0.4474394856930294], 'telephone': [0.4237785295709821, 0.2675547110945098, 0.38802190112164675, 0.35429852215070157], 'ice-cream-truck': [0.3622184181592557, 0.24479028114741808, 0.2208519755091849, 0.44980298121806833], 'no-broken-hearted-girl': [0.3943449704144327, 0.30545050792286255, 0.34915551675049866, 0.3259314708348415]}

# %%
votes = {}

for artist in test_songs:
    votes[artist[1]] = [0, 0, 0, 0]

# %%
with open('mturk_results.csv') as f:
    surveys = csv.reader(f, delimiter=',')
    for row in surveys:
        if row[0] != "HITId":
            responses = []
            for i in range(27,42):
                responses.append(row[i])
            j = 0
            for response in responses:
                if response == "Happy":
                    votes[test_songs[j][1]][0] += 1
                elif response == "Hate":
                    votes[test_songs[j][1]][1] += 1
                elif response == "Love":
                    votes[test_songs[j][1]][2] += 1
                elif response == "Sad":
                    votes[test_songs[j][1]][3] += 1
                j+=1
print(votes)
# Out:
# {'song': [15, 20, 26, 39], 'ego-remix': [3, 19, 19, 59], 'then-tell-me': [27, 4, 21, 48], 'honesty': [9, 64, 9, 18], 'you-are-my-rock': [18, 1, 66, 15], 'black-culture': [16, 3, 81, 0], 'all-i-could-do-was-cry': [28, 5, 13, 54], 'once-in-a-lifetime': [14, 9, 12, 65], 'waiting': [27, 12, 56, 5], 'slow-love': [18, 14, 23, 45], 'why-don-t-you-love-me': [14, 5, 35, 46], 'save-the-hero': [78, 2, 19, 1], 'telephone': [31, 24, 15, 30], 'ice-cream-truck': [55, 15, 12, 18], 'no-broken-hearted-girl': [26, 60, 9, 5], 'control': [0, 0, 0, 0], 'i-m-alone-now': [0, 0, 0, 0], 'poison': [0, 0, 0, 0], 'world-wide-women': [0, 0, 0, 0], 'beautiful-liar': [0, 0, 0, 0], 'beautiful-liar-spanish': [0, 0, 0, 0], 'beautiful-liar-spanglish-version': [0, 0, 0, 0], 'bienvenue': [0, 0, 0, 0], 'beutiful-liar-remix': [0, 0, 0, 0], 'he-still-loves-me-f-choir-from-fighting-temptations': [0, 0, 0, 0], 'bello-embustero': [0, 0, 0, 0], 'irreplable': [0, 0, 0, 0], 'the-first-day': [0, 0, 0, 0], 'my-man': [0, 0, 0, 0], 'what-s-it-gonna-be': [0, 0, 0, 0], 'if': [0, 0, 0, 0], 'a-girl-with-no-name': [0, 0, 0, 0], 'bello-embustero-beautiful-liar-spanish-version': [0, 0, 0, 0], 'vois-sur-ton-chemin': [0, 0, 0, 0], 'flaws-all': [0, 0, 0, 0], 'i-can-t-take-no-more': [0, 0, 0, 0], 'bonnie-and-clyde-ft-jay-z': [0, 0, 0, 0], 'keep-givin-your-love-to-me': [0, 0, 0, 0], 'listen': [0, 0, 0, 0], 'welcome-to-hollywood': [0, 0, 0, 0], 'my-first-time': [0, 0, 0, 0], 'still-in-love': [0, 0, 0, 0], 'daddy-hidden-track': [0, 0, 0, 0], 'angel': [0, 0, 0, 0], 'diamonds': [0, 0, 0, 0], 'everthing-i-do': [0, 0, 0, 0], 'world-wide-woman-www': [0, 0, 0, 0], 'what-s-good-with-you': [0, 0, 0, 0], 'amor-gitano': [0, 0, 0, 0], 'oye-listen-spanish-version': [0, 0, 0, 0], 'irreemplazable-nortena-remix': [0, 0, 0, 0], 'the-joy-of-pepsi-carmen': [0, 0, 0, 0], 'irreemplazable-irreplaceable-spanish-version': [0, 0, 0, 0], 'if-eu-asian-australian-edition': [0, 0, 0, 0], 'brown-eyes': [0, 0, 0, 0], 'why-me-lord': [0, 0, 0, 0], 'back-to-black': [0, 0, 0, 0], 'mine': [0, 0, 0, 0], 'superpower': [0, 0, 0, 0], 'haunted': [0, 0, 0, 0], 'flawless': [0, 0, 0, 0], 'partition': [0, 0, 0, 0], 'ghost': [0, 0, 0, 0], 'xo': [0, 0, 0, 0], 'single-ladies-put-a-ring-on-it': [0, 0, 0, 0], 'on-the-run': [0, 0, 0, 0], 'no-angel': [0, 0, 0, 0], 'rocket': [0, 0, 0, 0], 'blow': [0, 0, 0, 0], 'grown-woman': [0, 0, 0, 0], 'part-ii-on-the-run': [0, 0, 0, 0], 'standing-on-the-sun': [0, 0, 0, 0], 'blue': [0, 0, 0, 0], 'rise-up': [0, 0, 0, 0], 'bow-down-i-been-on': [0, 0, 0, 0], 'pretty-hurts': [0, 0, 0, 0], 'heaven': [0, 0, 0, 0], 'yonce': [0, 0, 0, 0], 'jealous': [0, 0, 0, 0], 'god-made-you-beautiful': [0, 0, 0, 0], 'drunk-in-love': [0, 0, 0, 0], 'baby-you-re-the-only-man': [0, 0, 0, 0], 'blind-trust': [0, 0, 0, 0], 'hair-crazy-in-love': [0, 0, 0, 0], 'i-m-glad-there-s-you': [0, 0, 0, 0], 'ice-cream': [0, 0, 0, 0], 'freakdum-dresses': [0, 0, 0, 0], 'hope-for-haiti-now': [0, 0, 0, 0], 'lesten': [0, 0, 0, 0], 'run-the-world-girls-remix': [0, 0, 0, 0], 'helo': [0, 0, 0, 0], 'daddy': [0, 0, 0, 0], 'speechless': [0, 0, 0, 0], 'cards-never-lie': [0, 0, 0, 0], 'listen-hidden-track': [0, 0, 0, 0], 'have-your-way': [0, 0, 0, 0], 'get-me-bodied': [0, 0, 0, 0], 'be-with-you': [0, 0, 0, 0], 'after-all-is-said-and-done': [0, 0, 0, 0], 'everything-i-do': [0, 0, 0, 0], 'lost-yo-mind': [0, 0, 0, 0], 'ring-the-alarm': [0, 0, 0, 0], 'oye-su-canto': [0, 0, 0, 0], 'naughty-girl': [0, 0, 0, 0], 'gift-from-virgo': [0, 0, 0, 0], 'dangerously-in-love': [0, 0, 0, 0], 'check-on-it': [0, 0, 0, 0], 'encore-for-the-fans-bonus-track': [0, 0, 0, 0], 'the-closer-i-get-to-you': [0, 0, 0, 0], 'i-m-leaving': [0, 0, 0, 0], 'creole-japan-bonus-track': [0, 0, 0, 0], 'he-s-my-man': [0, 0, 0, 0], 'in-da-club-remix': [0, 0, 0, 0], 'kitty-kat': [0, 0, 0, 0], 'get-me-bodied-extended-remix-bonus-track': [0, 0, 0, 0], 'work-it-out': [0, 0, 0, 0], 'upgrade-u': [0, 0, 0, 0], 'summertime-w-p-diddy': [0, 0, 0, 0], 'wishing-on-a-star': [0, 0, 0, 0], 'stop-that': [0, 0, 0, 0], ...

# %%
print(cos_sim)
# Out:
# {'song': [0.32556193644099224, 0.22631293464604638, 0.30357257109022256, 0.398654957721428], 'ego-remix': [0.40511656177228483, 0.2407950904288218, 0.27599055051522786, 0.41873723780541583], 'then-tell-me': [0.35782650107024183, 0.24740572530021182, 0.3555711935069523, 0.40093764179542374], 'honesty': [0.4995553400498957, 0.350520766500172, 0.46119483110523185, 0.421013858220757], 'you-are-my-rock': [0.4573520013478285, 0.28431275473681245, 0.49495460279512216, 0.4233194052391503], 'black-culture': [0.34566999995273007, 0.2003639177309171, 0.4023620717898138, 0.3574204309568076], 'all-i-could-do-was-cry': [0.426506551203229, 0.25369822001114734, 0.32330730109845646, 0.4612031544267265], 'once-in-a-lifetime': [0.38057608680352495, 0.2358070600414518, 0.25012659390930825, 0.4109036214264351], 'waiting': [0.31663854213827325, 0.22294962622482606, 0.3076771962550744, 0.3716847472528127], 'slow-love': [0.34540076616840043, 0.2410459704402548, 0.23695973478607932, 0.43986843883141097], 'why-don-t-you-love-me': [0.40475672956367187, 0.28012418951902035, 0.4136658420024277, 0.45900971787313755], 'save-the-hero': [0.3995109609135853, 0.2248965400975766, 0.39303214231641415, 0.4474394856930294], 'telephone': [0.4237785295709821, 0.2675547110945098, 0.38802190112164675, 0.35429852215070157], 'ice-cream-truck': [0.3622184181592557, 0.24479028114741808, 0.2208519755091849, 0.44980298121806833], 'no-broken-hearted-girl': [0.3943449704144327, 0.30545050792286255, 0.34915551675049866, 0.3259314708348415]}

# %%
data = {}
data['Songs'] = []
for i in range(1,16):
    data['Songs'].append('Song '+str(i))
data['Happy'] = []
data['Hate'] = []
data['Love'] = []
data['Sad'] = []
for key in votes:
    data['Happy'].append(votes[key][0])
    data['Hate'].append(votes[key][1])
    data['Love'].append(votes[key][2])
    data['Sad'].append(votes[key][3])
    
df = pd.DataFrame(data, columns = ['Songs', 'Happy', 'Hate', 'Love', 'Sad'])

plt.gcf().clear()

# Setting the positions and width for the bars
pos = list(range(len(data['Songs']))) 
width = 0.2 

# Plotting the bars
fig, ax = plt.subplots(figsize=(15,5))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        df['Happy'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=df['Songs'][0]) 

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        df['Hate'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=df['Songs'][1]) 

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['post_score'] data,
        df['Love'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the third value in first_name
        label=df['Songs'][2])

plt.bar([p + width*3 for p in pos], 
        #using df['post_score'] data,
        df['Sad'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#ffff00', 
        # with label the third value in first_name
        label=df['Songs'][3])

# Set the y axis label
ax.set_ylabel('Votes')

# Set the chart's title
ax.set_title('Mechanical Turk Results')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(df['Songs'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(df['Happy'] + df['Hate'] + df['Love'] + df['Sad'])] )
plt.legend(['Happy', 'Hate', 'Love', 'Sad'], loc='upper right')
# plt.gcf().clear()
plt.savefig("Mechanical Turk Results.svg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f5ea39779af6> in <module>()
#      13     data['Sad'].append(votes[key][3])
#      14
# ---> 15 df = pd.DataFrame(data, columns = ['Songs', 'Happy', 'Hate', 'Love', 'Sad'])
#      16
#      17 plt.gcf().clear()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     264                                  dtype=dtype, copy=copy)
#     265         elif isinstance(data, dict):
# --> 266             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     267         elif isinstance(data, ma.MaskedArray):
#     268             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     358             # raise ValueError if only scalars in dict
#     359             if index is None:
# --> 360                 extract_index(list(data.values()))
#     361
#     362             # prefilter if columns passed
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    5444             lengths = list(set(raw_lengths))
#    5445             if len(lengths) > 1:
# -> 5446                 raise ValueError('arrays must all be same length')
#    5447
#    5448             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
data = {}
data['Songs'] = []
for i in range(1,16):
    data['Songs'].append('Song '+str(i))
data['Happy'] = []
data['Hate'] = []
data['Love'] = []
data['Sad'] = []
for key in cos_sim:
    data['Happy'].append(cos_sim[key][0])
    data['Hate'].append(cos_sim[key][1])
    data['Love'].append(cos_sim[key][2])
    data['Sad'].append(cos_sim[key][3])
    
df = pd.DataFrame(data, columns = ['Songs', 'Happy', 'Hate', 'Love', 'Sad'])

plt.gcf().clear()

# Setting the positions and width for the bars
pos = list(range(len(data['Songs']))) 
width = 0.2 

# Plotting the bars
fig, ax = plt.subplots(figsize=(15,5))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        df['Happy'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=df['Songs'][0]) 

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        df['Hate'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=df['Songs'][1]) 

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['post_score'] data,
        df['Love'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the third value in first_name
        label=df['Songs'][2])

plt.bar([p + width*3 for p in pos], 
        #using df['post_score'] data,
        df['Sad'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#ffff00', 
        # with label the third value in first_name
        label=df['Songs'][3])

# Set the y axis label
ax.set_ylabel('Votes')

# Set the chart's title
ax.set_title('Cosine Similarity Results')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(df['Songs'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, .6] )
plt.legend(['Happy', 'Hate', 'Love', 'Sad'], loc='upper right')
# plt.gcf().clear()
plt.savefig("Cosine Similarity Results.svg")

# %%
f = open('Song Order.txt', 'w')
for key in cos_sim:
    for song in test_songs:
        if song[1] == key:
            f.write(song[1] + " by " + song[0] + "\n")
f.close()
